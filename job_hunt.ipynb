# %% [markdown]
# ![Описание изображения](https://media.licdn.com/dms/image/C4D12AQHGhy-T0hzcFg/article-cover_image-shrink_720_1280/0/1650121428837?e=2147483647&v=beta&t=yn49IAiqvCD8AyvG8JTxP53lQqmA8AkTwLkYFmMt7S0)

# %% [markdown]
# # Job Hunter 2023
#
# <div class="alert alert-info"> <b>Цель, как в хлам опьяневшая барышня -
# её недоступность вещь очень сомнительная.</b> </div>

# %% [markdown]
# ## Легенда
#
# **Тип:** **горячий поиск** (самостоятельные отклики и статус "Ищу работу")
# Дата начала  **27.06.2023**
# Основное направление  **Data Analyst**
# Дополнительные направления **Аналитик BI, Бизнес-аналитик**
# Релевантный опыт **9 месяцев(6+3)**
# ЗП-ожидание : **140-160 gross**
# Формат-ожидание:  **гибрид (2+3, 3+2)**
#
# **Маркетинг**: 728 руб. Подсвет резюме + автоподнятие на 2 недели
#
# **Поиск-бекграунд**:
# дата начала холодного поиска - **01.06.2023**
# Формат поиска - отклики на отобранные вакансии
#
# Всего откликов: 14
# Всего собеседований: 3
# Всего отказов после собеса: 1
# Всего отказов на портале: 3
# Офферы: 0

# %% [markdown]
# ### 27.06.2023
#
# <div class="alert alert-info"> <b>Скорее дайте мне барную карту я сверю координаты перед дорогой!</b> </div>
#
# | Активности           | Кол-во                |
# |----------------------|-----------------------|
# | Просмотры            |           18          |
# | Отклики              |           6           |
# | Отказы  работодатель |           0           |
# | Отказы  соискатель   |           1           |
# | Контакты с HR        |           1           |
# | Согласование собес.  |           1           |
# | Собеседования        |           0           |
# | Тестовые             |           0           |
#
# **Контекст**
# Пришло время выйти на рынок труда. Текущий работодатель не оправдал ожиданий. 1-2 удаленки в неделю после испытательного(обещание) были трансформированы в "ну в будущем возможно 1-2 в месяц". Работодатель малоадекватен. Перспективы нулевые, ЗП смешная. Мой тимлид пытается навесить на меня функционал тестировщика, аналитика, консультанта CRM, а когда я морожусь, укоряет что я слишком много зарабатываю. Всё как в том меме - на арене цирка клоуны - дегенераты.
# Предыдущий горячийпоиск работы был завершен в конце марта.
# К холодному поиску я перешёл в начале июне, откликался на выбранные вакансии, получил 3 собеса. Все неудачно.
# За это время резюме пережило 4 версии, 3 версии гитхаб, сопроводиловки доверяю ГПТ.
# Пришло время сделать шаг вперед, как по формату, так и по деньгам.
# Сколько это займёт времени? Сложно сказать. Может месяц, может 3.
# **Ориентир по сроку - к октябрю должен быть приемлимый результат.**
#
# **Дневник**
# В рамках первого дня сделал 6 откликов. Также много просмотров набежало за счёт парсеров (**Гипотеза**: большая часть просмотров первого дня связана с работой парсеров, а не реальных людей).
# Получил первый приглос на собеседование, унылая вакансия, офисный формат, отказался сразу, на следующий день они свой отказ прислали.
# Так же договорился отсобеситься на QV в четверг. Это фидбек по холодному поиску.

# %% [markdown]
# ### 28.06.2023
#
# <div class="alert alert-info"> <b>Вот меня занесло-то, моя жизнь - это скоростной Highway</b> </div>
#
# | Активности           | Кол-во                |
# |----------------------|-----------------------|
# | Просмотры            |           10          |
# | Отклики              |           0           |
# | Отказы  работодатель |           1           |
# | Отказы  соискатель   |           0           |
# | Контакты с HR        |           0           |
# | Согласование собес.  |           0           |
# | Собеседования        |           0           |
# | Тестовые             |           0           |
#
#
# **Дневник**
# В рамках второго дня откликов не делал. Подходящие вакансии в избранном закончились.
# Подьехал отказ от ШАФТа, от которого я отказался сам.
# Еще прилетел отказ на одну из вакашек РосБанка, на которую откликался недели 3 назад. Первый отказ от Росбанка, до этого просто игнор был.
# Едем дальше.

# %% [markdown]
# ### 29.06.2023
#
# <div class="alert alert-info"> <b>Суета и переезды выматывают, по-ходу я заблудился немного.</b> </div>
#
# | Активности           | Кол-во                |
# |----------------------|-----------------------|
# | Просмотры            |           11          |
# | Отклики              |           7           |
# | Отказы  работодатель |           1           |
# | Отказы  соискатель   |           0           |
# | Контакты с HR        |           0           |
# | Согласование собес.  |           0           |
# | Собеседования        |           1           |
# | Тестовые             |           0           |
#
#
# **Дневник**
# В рамках третьего дня получился очередной потешный собес в Пульс. Суть собеса в том, что претендовал на аналитика. Перед собесом озвучивал свой опыт, что он только пользовательский.
# В итоге собес закончился на вопрос понимаю ли я особенности коддинга на Клике. К слову, в вакансии про код не было ничего. Было про Confluence, про Jira.
# Когда я услышал, что собеситься будем Вадим, я иронично улыбнулся. Удачных Вадимов я еще не встречал. Из интересного Вадим озвучил, что 150 для человека знающего Питон очень мало.

# %% [markdown]
# ### 30.06.2023
#
# <div class="alert alert-info"> <b>Надо карабкаться к цели, и пусть не пугает, что не пережить всех событий нам..</b> </div>
#
# | Активности           | Кол-во                |
# |----------------------|-----------------------|
# | Просмотры            |           7           |
# | Отклики              |           1           |
# | Отказы  работодатель |           0           |
# | Отказы  соискатель   |           0           |
# | Контакты с HR        |           0           |
# | Согласование собес.  |           0           |
# | Собеседования        |           0           |
# | Тестовые             |           0           |
#
#
# **Дневник**
# Четвертый день прошёл с оттенком болезненности и борьбы с недугом. В связи с этим пониженная активность.
